# %% [markdown]
# ## 제가 교육 중에 작성하는 모든 코드는 나중에 공유 드립니다.

# %%
import numpy as np
import pandas as pd

# %%
df_s = pd.DataFrame(dict(v1 = [100, 200, 300],
                         v2 = [400, 500, 600],
                         shape = ["A", "B", "C"]))
df_s

# %%
df_s.iloc[:2, ]
# Out:
#     v1   v2 shape
# 0  100  400     A
# 1  200  500     B

# %%
df_s.loc[:2, ]
# Out:
#     v1   v2 shape
# 0  100  400     A
# 1  200  500     B
# 2  300  600     C

# %%
df_s.v1
# Out:
# 0    100
# 1    200
# 2    300
# Name: v1, dtype: int64

# %%
df_s.shape
# Out:
# (3, 3)

# %%
df_s["shape"]
# Out:
# 0    A
# 1    B
# 2    C
# Name: shape, dtype: object

# %%
df_s.iloc[:, :-1] # 뒤에서 첫 번째. drop last column
# Out:
#     v1   v2
# 0  100  400
# 1  200  500
# 2  300  600

# %%
df_s.loc[:, "v2":]
# Out:
#     v2 shape
# 0  400     A
# 1  500     B
# 2  600     C

# %%
df_s.loc[df_s["v1"] == 200, ]
# Out:
#     v1   v2 shape
# 1  200  500     B

# %%
df_s.loc[df_s["v1"] != 200, ]
# Out:
#     v1   v2 shape
# 0  100  400     A
# 2  300  600     C

# %%
df_s["v1"] == 200
# Out:
# 0    False
# 1     True
# 2    False
# Name: v1, dtype: bool

# %%
~(df_s["v1"] == 200)
# Out:
# 0     True
# 1    False
# 2     True
# Name: v1, dtype: bool

# %%
# df_s.loc[df_s["v1"] != 200, ]
df_s.loc[~(df_s["v1"] == 200), ]
# Out:
#     v1   v2 shape
# 0  100  400     A
# 2  300  600     C

# %%
df_s.loc[(df_s["v1"] == 200) & (df_s["v2"] == 600), ]
# Out:
# Empty DataFrame
# Columns: [v1, v2, shape]
# Index: []

# %%
df_s.loc[(df_s["v1"] == 200) | (df_s["v2"] == 600), ]
# Out:
#     v1   v2 shape
# 1  200  500     B
# 2  300  600     C

# %%
condi_1 = df_s["v1"] == 200
condi_2 = df_s["v2"] == 500
df_s.loc[condi_1 & condi_2, ]
# Out:
#     v1   v2 shape
# 1  200  500     B

# %%
df_s.loc[(df_s["shape"] == "A") | (df_s["shape"] == "C"), ]
# Out:
#     v1   v2 shape
# 0  100  400     A
# 2  300  600     C

# %%
df_s.loc[df_s["shape"].isin(["A", "C"]), ]
# Out:
#     v1   v2 shape
# 0  100  400     A
# 2  300  600     C

# %%
df_s.loc[~df_s["shape"].isin(["A", "C"]), ]
# Out:
#     v1   v2 shape
# 1  200  500     B

# %%
df = pd.read_csv("krx_202105_utf8.csv")
df.head(2)
# Out:
#        지수명        종가     대비   등락률        시가        고가        저가        거래량  \
# 0  KRX 300   1901.05 -11.63 -0.61   1913.15   1929.94   1896.65  279548840
# 1  KTOP 30  11520.28 -86.30 -0.74  11609.44  11702.14  11490.84   50048566
#
#              거래대금            상장시가총액        날짜
# 0  13488481375036  2028800954161500  20210503
# 1   5645660149606  1208343758559140  20210503

# %%
df_sub = df.loc[df["지수명"] == "KRX 300", ]
df_sub

# %%
df.loc[df["종가"] == df["종가"].max(), ["지수명", "종가", "날짜"]]
# Out:
#          지수명        종가        날짜
# 117  KTOP 30  11869.29  20210510

# %%
df["종가"].idxmax()
# Out:
# 117

# %%
df.loc[117, ["지수명", "종가", "날짜"]]
# Out:
# 지수명     KTOP 30
# 종가     11869.29
# 날짜     20210510
# Name: 117, dtype: object

# %%
df.loc[df["종가"].idxmax(), ["지수명", "종가", "날짜"]]
# Out:
# 지수명     KTOP 30
# 종가     11869.29
# 날짜     20210510
# Name: 117, dtype: object

# %%
df.loc[[df["종가"].idxmax()], ["지수명", "종가", "날짜"]]
# Out:
#          지수명        종가        날짜
# 117  KTOP 30  11869.29  20210510

# %% [markdown]
# * 결측치: https://datadoctorblog.com/2023/04/24/Py-Basic-Pandas-Missing/

# %%
df = pd.read_csv("iris_missing.csv")
df_sub = df.head()
df_sub
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          NaN           NaN          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df_sub.info()

# %%
df_sub.count() # 거의 사용하지 않음.

# %%
df_sub.dtypes
# Out:
# Sepal.Length    float64
# Sepal.Width     float64
# Petal.Length    float64
# Petal.Width     float64
# Species          object
# dtype: object

# %%
df_sub.isna().sum() # 🔥🔥
# Out:
# Sepal.Length    0
# Sepal.Width     1
# Petal.Length    1
# Petal.Width     0
# Species         0
# dtype: int64

# %%
df_sub.isna()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  Species
# 0         False         True          True        False    False
# 1         False        False         False        False    False
# 2         False        False         False        False    False
# 3         False        False         False        False    False
# 4         False        False         False        False    False

# %%
df_sub1 = df_sub.loc[df_sub["Sepal.Width"].isna(), ]
df_sub1
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          NaN           NaN          0.2  setosa

# %%
df_sub2 = df_sub.loc[df_sub["Sepal.Width"].notna(), ]
df_sub2
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df_sub3 = df_sub.dropna()
df_sub3
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df_sub.loc[:, "Sepal.Width"] = df_sub["Sepal.Width"].fillna(-999)
df_sub["Petal.Length"] = df_sub["Petal.Length"].fillna(df_sub["Petal.Length"].mean())

# %%
df_sub

# %%
df_sub2 = df.head().copy() # .copy() 또는 .reset_index(drop = True) 
df_sub2.loc[:, "Sepal.Width"] = df_sub2["Sepal.Width"].fillna(-999)
df_sub2["Petal.Length"] = df_sub2["Petal.Length"].fillna(df_sub2["Petal.Length"].mean())
df_sub2
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1       -999.0           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df_sub3 = df.tail()
# df_sub3.reset_index()
df_sub3.reset_index(drop = True)

# %%
df_sub.set_index("Species").reset_index() # 특정 변수를 기존 위치에 관계 없이 가장 앞으로 옮길 수 있음.
# Out:
#   Species  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 0  setosa           5.1       -999.0           1.4          0.2
# 1  setosa           4.9          3.0           1.4          0.2
# 2  setosa           4.7          3.2           1.3          0.2
# 3  setosa           4.6          3.1           1.5          0.2
# 4  setosa           5.0          3.6           1.4          0.2

# %% [markdown]
# * 원소/조합 세기: https://datadoctorblog.com/2023/04/04/Py-Basic-Pandas-Counting/
# * crosstab(): https://datadoctorblog.com/2023/05/06/Py-Basic-Pandas-Crosstab/

# %%
df = pd.read_csv("bike.csv")
df.head(1)

# %%
df["season"].unique()
# Out:
# array([1, 2, 3, 4])

# %%
df["season"].nunique() # number of ~
# Out:
# 4

# %%
df["season"].drop_duplicates() # 단변수는 Series, 다중변수는 DataFrame
# Out:
# 0       1
# 1323    2
# 2690    3
# 4055    4
# Name: season, dtype: int64

# %%
# df.iloc[1321:1325, ]

# %%
df["season"].value_counts()

# %%
df["season"].value_counts().sort_index()
# Out:
# season
# 1    2686
# 2    2733
# 3    2733
# 4    2734
# Name: count, dtype: int64

# %%
df["season"].value_counts(normalize = True)
# Out:
# season
# 4    0.251148
# 2    0.251056
# 3    0.251056
# 1    0.246739
# Name: proportion, dtype: float64

# %%
df[["season", "holiday"]].drop_duplicates()
# Out:
#       season  holiday
# 0          1        0
# 372        1        1
# 1323       2        0
# 1658       2        1
# 2690       3        0
# 2762       3        1
# 4055       4        0
# 4271       4        1

# %%
pd.crosstab(df["season"], df["holiday"])
# Out:
# holiday     0   1
# season
# 1        2615  71
# 2        2685  48
# 3        2637  96
# 4        2638  96

# %% [markdown]
# * .groupby(): https://datadoctorblog.com/2023/04/28/Py-Basic-Pandas-Groupby/

# %%
df = pd.read_csv("diamonds.csv")
df.head(2)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31

# %%
df.groupby("cut")["price"].max()
# Out:
# cut
# Fair         18574
# Good         18788
# Ideal        18806
# Premium      18823
# Very Good    18818
# Name: price, dtype: int64

# %%
df_g1 = df.groupby("cut")["price"].max().reset_index()
df_g1
# Out:
#          cut  price
# 0       Fair  18574
# 1       Good  18788
# 2      Ideal  18806
# 3    Premium  18823
# 4  Very Good  18818

# %%
df.groupby("cut")[["price", "carat"]].max()
# Out:
#            price  carat
# cut
# Fair       18574   5.01
# Good       18788   3.01
# Ideal      18806   3.50
# Premium    18823   4.01
# Very Good  18818   4.00

# %%
df.groupby("cut")[["price", "carat"]].agg(["min", "max"])
# Out:
#           price        carat
#             min    max   min   max
# cut
# Fair        337  18574  0.22  5.01
# Good        327  18788  0.23  3.01
# Ideal       326  18806  0.20  3.50
# Premium     326  18823  0.20  4.01
# Very Good   336  18818  0.20  4.00

# %%
df_g2 = df.groupby(["cut", "color"])["carat"].max().reset_index()
df_g2.head()
# Out:
#     cut color  carat
# 0  Fair     D   3.40
# 1  Fair     E   2.04
# 2  Fair     F   2.58
# 3  Fair     G   2.60
# 4  Fair     H   4.13

# %%
df_g3 = df.groupby("cut")[["price", "carat"]].agg({"price": "min", 
                                                   "carat": "max"}).reset_index() # 🎯🎯🎯 시험 기출 예제
df_g3.head()
# Out:
#          cut  price  carat
# 0       Fair    337   5.01
# 1       Good    327   3.01
# 2      Ideal    326   3.50
# 3    Premium    326   4.01
# 4  Very Good    336   4.00

# %% [markdown]
# * 문자데이터 핸들링: https://datadoctorblog.com/2023/04/20/Py-Basic-Pandas-String-Data/

# %%
df_tx = pd.DataFrame(dict(v1 = [100, 200, 300],
                          v2 = ["abc", "aaa", "ccc"],
                          v3 = [123, "1234-5678", "010-1234-5678"]))
df_tx
# Out:
#     v1   v2             v3
# 0  100  abc            123
# 1  200  aaa      1234-5678
# 2  300  ccc  010-1234-5678

# %%
df_tx["v2"].replace("a", "🔥")
# Out:
# 0    abc
# 1    aaa
# 2    ccc
# Name: v2, dtype: object

# %%
df_tx["v2"].replace("aaa", "🔥")
# Out:
# 0    abc
# 1      🔥
# 2    ccc
# Name: v2, dtype: object

# %%
df_tx["v2"].replace({"aaa": "🔥", "ccc": "🩵"})
# Out:
# 0    abc
# 1      🔥
# 2      🩵
# Name: v2, dtype: object

# %%
df_tx["v2"].str.replace("a", "🔥")
# Out:
# 0    🔥bc
# 1    🔥🔥🔥
# 2    ccc
# Name: v2, dtype: object

# %%
df_tx["v2"].str.replace("aaa", "🔥")
# Out:
# 0    abc
# 1      🔥
# 2    ccc
# Name: v2, dtype: object

# %%
df_tx["v2"].str.contains("a")
# Out:
# 0     True
# 1     True
# 2    False
# Name: v2, dtype: bool

# %%
~df_tx["v2"].str.contains("a")
# Out:
# 0    False
# 1    False
# 2     True
# Name: v2, dtype: bool

# %%
df_tx["v5"] = df_tx["v2"].str.replace("aaa", "🔥")
df_tx

# %%
df_tx["v3"].str.split("-")
# Out:
# 0                  NaN
# 1         [1234, 5678]
# 2    [010, 1234, 5678]
# Name: v3, dtype: object

# %%
df_tx["v4"] = df_tx["v3"].astype("str")
df_tx["v4"][0]
# Out:
# '123'

# %%
df_tx["v4"].str.split("-")
# Out:
# 0                [123]
# 1         [1234, 5678]
# 2    [010, 1234, 5678]
# Name: v4, dtype: object

# %%
df_tx["v4"].str.split("-").explode()
# Out:
# 0     123
# 1    1234
# 1    5678
# 2     010
# 2    1234
# 2    5678
# Name: v4, dtype: object

# %%
df_tx_v4 = df_tx["v4"].str.split("-", expand = True)
df_tx_v4
# Out:
#       0     1     2
# 0   123  None  None
# 1  1234  5678  None
# 2   010  1234  5678

# %%
df_tx_v4_2 = df_tx_v4.add_prefix("v4_")
df_tx_v4_3 = df_tx_v4_2.fillna("🥗")
df_tx_v4_3
# Out:
#    v4_0  v4_1  v4_2
# 0   123     🥗     🥗
# 1  1234  5678     🥗
# 2   010  1234  5678

# %% [markdown]
# * 시간데이터 핸들링: https://datadoctorblog.com/2023/04/14/Py-Basic-Pandas-Time-Data/

# %%
ser_t1 = pd.Series(["2077-12-18", "2077-12-19", "2077-12-20"])
ser_t2 = pd.Series(["2077년 12월 18일", "2077년 12월 19일", "2077년 12월 20일"])
ser_t3 = pd.Series([20241218, 20241219, 20241220])
ser_t4 = pd.Series([1234, 2345, 3456])

# %%
pd.to_datetime(ser_t1)
# Out:
# 0   2077-12-18
# 1   2077-12-19
# 2   2077-12-20
# dtype: datetime64[ns]

# %%
# pd.to_datetime(ser_t2) # Error!!!

# %% [markdown]
# https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior

# %%
pd.to_datetime(ser_t2, format = "%Y년 %m월 %d일")
# Out:
# 0   2077-12-18
# 1   2077-12-19
# 2   2077-12-20
# dtype: datetime64[ns]

# %%
pd.to_datetime(ser_t3)
# Out:
# 0   1970-01-01 00:00:00.020241218
# 1   1970-01-01 00:00:00.020241219
# 2   1970-01-01 00:00:00.020241220
# dtype: datetime64[ns]

# %%
pd.to_datetime(ser_t3.astype("str"))
# Out:
# 0   2024-12-18
# 1   2024-12-19
# 2   2024-12-20
# dtype: datetime64[ns]

# %%
pd.to_datetime(ser_t4)
# Out:
# 0   1970-01-01 00:00:00.000001234
# 1   1970-01-01 00:00:00.000002345
# 2   1970-01-01 00:00:00.000003456
# dtype: datetime64[ns]

# %%
pd.to_datetime(ser_t4, origin = "2070-01-01", unit = "m")
# Out:
# 0   2070-01-01 20:34:00
# 1   2070-01-02 15:05:00
# 2   2070-01-03 09:36:00
# dtype: datetime64[ns]

# %%
df_bike = pd.read_csv("bike.csv")
df_dt2 = df_bike[["datetime"]].copy() # 대괄호 2개!! (DataFrame 객체 유형 유지 위함)

# %%
df_dt2["datetime"] = pd.to_datetime(df_dt2["datetime"])
df_dt2["date"  ] = df_dt2["datetime"].dt.date
df_dt2["yyyymm"] = df_dt2["datetime"].dt.strftime("%Y-%m") # 기출 🎯
df_dt2["year"  ] = df_dt2["datetime"].dt.year
df_dt2["month" ] = df_dt2["datetime"].dt.month
df_dt2["wday"  ] = df_dt2["datetime"].dt.weekday
df_dt2["wend"  ] = np.where(df_dt2["wday"] >= 5, 1, 0)
df_dt2["hour"  ] = df_dt2["datetime"].dt.hour
df_dt2["dt_s9h"] = df_dt2["datetime"] + pd.to_timedelta(9, unit = "h")

# %%
df_dt2.head(2)
# Out:
#              datetime        date   yyyymm  year  month  wday  wend  hour  \
# 0 2011-01-01 00:00:00  2011-01-01  2011-01  2011      1     5     1     0
# 1 2011-01-01 01:00:00  2011-01-01  2011-01  2011      1     5     1     1
#
#                dt_s9h
# 0 2011-01-01 09:00:00
# 1 2011-01-01 10:00:00

# %%
df_dt = pd.DataFrame(dict(date = ["2077-08-01", "2077-08-02", "2077-08-03"]))
df_dt["origin"] = "2077-01-01"
df_dt["date"  ] = pd.to_datetime(df_dt["date"])
df_dt["origin"] = pd.to_datetime(df_dt["origin"])
df_dt["diff"  ] = df_dt["date"] - df_dt["origin"]
df_dt["diff_d"] = df_dt["diff"].dt.days
df_dt
# Out:
#         date     origin     diff  diff_d
# 0 2077-08-01 2077-01-01 212 days     212
# 1 2077-08-02 2077-01-01 213 days     213
# 2 2077-08-03 2077-01-01 214 days     214

# %%
df_dt.dtypes
# Out:
# date       datetime64[ns]
# origin     datetime64[ns]
# diff      timedelta64[ns]
# diff_d              int64
# dtype: object

# %%
(df_dt["date"] - pd.to_datetime("2077-01-01")).dt.days
# Out:
# 0    212
# 1    213
# 2    214
# Name: date, dtype: int64

# %%
df_t = pd.DataFrame(dict(date = pd.date_range("2024-01-01", "2024-01-07"),
                         v = [100, 200, 300, np.nan, 500, 600, 700]))

df_t["v_s1"] = df_t["v"].shift(1)
df_t["v_s2"] = df_t["v"].shift(2)
df_t["v_sn1"] = df_t["v"].shift(-1)
df_t["v_fill_1"] = np.where(df_t["v"].isna(),
                            (df_t["v_s1"] + df_t["v_sn1"]) / 2,
                            df_t["v"])
df_t["v_fill_2"] = df_t["v"].interpolate()

# %%
df_t
# Out:
#         date      v   v_s1   v_s2  v_sn1  v_fill_1  v_fill_2
# 0 2024-01-01  100.0    NaN    NaN  200.0     100.0     100.0
# 1 2024-01-02  200.0  100.0    NaN  300.0     200.0     200.0
# 2 2024-01-03  300.0  200.0  100.0    NaN     300.0     300.0
# 3 2024-01-04    NaN  300.0  200.0  500.0     400.0     400.0
# 4 2024-01-05  500.0    NaN  300.0  600.0     500.0     500.0
# 5 2024-01-06  600.0  500.0    NaN  700.0     600.0     600.0
# 6 2024-01-07  700.0  600.0  500.0    NaN     700.0     700.0

# %% [markdown]
# * .melt(): https://datadoctorblog.com/2023/05/07/Py-Basic-Pandas-Melt/

# %%
df_e = pd.read_csv("elec_load_2017_7d.csv")
df_e.head(3)
# Out:
#    YEAR  MONTH  DAY   X1HR   X2HR   X3HR   X4HR   X5HR   X6HR   X7HR  ...  \
# 0  2017      1    1  60178  57862  56165  55135  54450  54401  54147  ...
# 1  2017      1    2  57067  55148  53983  53571  54027  55388  57753  ...
# 2  2017      1    3  66263  64233  63194  62461  62649  63396  65098  ...
#
#    X15HR  X16HR  X17HR  X18HR  X19HR  X20HR  X21HR  X22HR  X23HR  X24HR
# 0  49213  49357  50362  53115  55205  55437  55348  55790  58195  59330
# 1  72228  71945  72641  73387  72294  69989  67893  66504  67435  69275
# 2  75576  75168  75791  75922  75469  73118  70769  68726  69593  71346
#
# [3 rows x 27 columns]

# %%
df_e_m1 = df_e.melt(id_vars = ["YEAR", "MONTH", "DAY"])
df_e_m1.head(2)
# Out:
#    YEAR  MONTH  DAY variable  value
# 0  2017      1    1     X1HR  60178
# 1  2017      1    2     X1HR  57067

# %%
df_e_m2 = df_e.melt(id_vars = ["YEAR", "MONTH", "DAY"], var_name = "HOUR", value_name = "LOAD")
df_e_m2.head(2)
# Out:
#    YEAR  MONTH  DAY  HOUR   LOAD
# 0  2017      1    1  X1HR  60178
# 1  2017      1    2  X1HR  57067

# %%
df_e_m2["h1"] = df_e_m2["HOUR"].str.replace("X", "").str.replace("HR", "")
# regex: 정규표현식 Regular Expression
df_e_m2["h2"] = df_e_m2["HOUR"].str.replace("X|HR", "", regex = True) # X 또는 HR
df_e_m2["h3"] = df_e_m2["HOUR"].str.replace("[A-Z]", "", regex = True) # 영문 대문자
df_e_m2["h4"] = df_e_m2["HOUR"].str.replace("[^0-9]", "", regex = True) # 숫자를 제외한 나머지
df_e_m2.head()

# %%
df_e_m2.dtypes

# %%
df.head(2) # <- diamonds
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31

# %%
df_g1 = df.groupby(["cut", "color"])["price"].mean().round(1).reset_index()
df_g2 = pd.crosstab(index = df["cut"], columns = df["color"], values = df["price"], aggfunc = "mean").round(1)
df_g3 = df.pivot_table(index = "cut", columns = "color", values = "price", aggfunc = "mean").round(1)

# %%
df_g1.head()

# %%
df_g2

# %%
df_g3
# Out:
# color           D       E       F       G       H       I       J
# cut
# Fair       4291.1  3682.3  3827.0  4239.3  5135.7  4685.4  4975.7
# Good       3405.4  3423.6  3495.8  4123.5  4276.3  5078.5  4574.2
# Ideal      2629.1  2597.6  3374.9  3720.7  3889.3  4452.0  4918.2
# Premium    3631.3  3538.9  4324.9  4500.7  5216.7  5946.2  6294.6
# Very Good  3470.5  3214.7  3778.8  3872.8  4535.4  5255.9  5103.5

# %%
df_bike = pd.read_csv("bike.csv")
df_b1 = df_bike.iloc[ :4, 4:7]
df_b2 = df_bike.iloc[1:5, 5:8]

# %%
df_bind1 = pd.concat([df_b1, df_b2])
df_bind1.isna().sum()
# Out:
# weather     4
# temp        0
# atemp       0
# humidity    4
# dtype: int64

# %%
pd.concat([df_b1, df_b2], axis = 1)

# %%
pd.concat([df_b1, df_b2.reset_index(drop = True).add_suffix("_y")], axis = 1)

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df_sub1 = df.loc[df["cut"] != "Ideal", ]
df_sub2 = df.loc[~df["cut"].isin(["Premium", "Good"]), ]

# %%
df_sub1_g = df_sub1.groupby("cut")["price"].mean().reset_index()
df_sub2_g = df_sub2.groupby("cut")["price"].mean().reset_index()

# %%
df_join1 = pd.merge(df_sub1_g, df_sub2_g, on = "cut")
df_join1
# Out:
#          cut      price_x      price_y
# 0       Fair  4358.757764  4358.757764
# 1  Very Good  3981.759891  3981.759891

# %%
df_join2 = pd.merge(df_sub1_g, df_sub2_g, on = "cut", how = "left")
df_join2
# Out:
#          cut      price_x      price_y
# 0       Fair  4358.757764  4358.757764
# 1       Good  3928.864452          NaN
# 2    Premium  4584.257704          NaN
# 3  Very Good  3981.759891  3981.759891

# %%
df_join3 = pd.merge(df_sub1_g, df_sub2_g.rename(columns = {"price": "price2"}), on = "cut", how = "left")
df_join3
# Out:
#          cut        price       price2
# 0       Fair  4358.757764  4358.757764
# 1       Good  3928.864452          NaN
# 2    Premium  4584.257704          NaN
# 3  Very Good  3981.759891  3981.759891

# %%
# 데이터프레임에서 사용하는 것은 x 에 Series 객체가 들어감.
df.groupby("cut")["price"].agg(lambda x: round(x.mean(), 1) + 1000000)

# %%
def udf_1(x):
    return round(x.mean(), 1) + 1000000

# %%
df.groupby("cut")["price"].agg(udf_1)
# Out:
# cut
# Fair         1004358.8
# Good         1003928.9
# Ideal        1003457.5
# Premium      1004584.3
# Very Good    1003981.8
# Name: price, dtype: float64

# %%
df.head(2)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31

# %%
df["clarity"].unique()
# Out:
# array(['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF'],
#       dtype=object)

# %%
df_s = df.loc[df["clarity"].str.contains("^S"), ] # S로 시작하는.
df_s.head()
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 0    0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1    0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 4    0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 7    0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 10   0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73
